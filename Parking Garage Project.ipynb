# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
# Your Code will go here
class ParkingGarage:
    def __init__(self, total_tickets, total_parking_spaces):
        self.tickets = list(range(1, total_tickets + 1))
        self.parkingSpaces = list(range(1, total_parking_spaces + 1))
        self.currentTicket = {}

    def takeTicket(self):
        if not self.tickets or not self.parkingSpaces:
            print("Sorry, the garage is full. No tickets available.")
            return
        ticket_number = self.tickets.pop(0)
        parking_space = self.parkingSpaces.pop(0)
        self.currentTicket = {
            "ticket_number": ticket_number,
            "parking_space": parking_space,
            "paid": False
        }
        print(f"Ticket {ticket_number} issued. Please proceed to parking space {parking_space}.")

    def payForParking(self):
        if not self.currentTicket:
            print("Please take a ticket first.")
            return

        if self.currentTicket["paid"]:
            print("Your ticket has already been paid. You have 15 minutes to leave.")
            return

        amount = input("Please enter the amount to pay for parking: ")
        if amount:
            self.currentTicket["paid"] = True
            print("Payment successful. Your ticket has been paid. You have 15 minutes to leave.")
        else:
            print("No payment received. Your ticket is still unpaid.")

    def leaveGarage(self):
        if not self.currentTicket:
            print("Please take a ticket first.")
            return

        if self.currentTicket["paid"]:
            print("Thank you. Have a nice day!")
            self.parkingSpaces.append(self.currentTicket["parking_space"])
            self.tickets.append(self.currentTicket["ticket_number"])
            self.currentTicket = {}
        else:
            print("Payment is required before leaving the garage.")


if __name__ == "__main__":
    garage = ParkingGarage(total_tickets=50, total_parking_spaces=50)

 
    garage.takeTicket()
    garage.payForParking()
    garage.leaveGarage()

    garage.takeTicket()
    garage.leaveGarage()

   
    for _ in range(50):
        garage.takeTicket()

   
    garage.takeTicket()
# Out:
# Ticket 1 issued. Please proceed to parking space 1.
# Payment successful. Your ticket has been paid. You have 15 minutes to leave.
# Thank you. Have a nice day!
# Ticket 2 issued. Please proceed to parking space 2.
# Payment is required before leaving the garage.
# Ticket 3 issued. Please proceed to parking space 3.
# Ticket 4 issued. Please proceed to parking space 4.
# Ticket 5 issued. Please proceed to parking space 5.
# Ticket 6 issued. Please proceed to parking space 6.
# Ticket 7 issued. Please proceed to parking space 7.
# Ticket 8 issued. Please proceed to parking space 8.
# Ticket 9 issued. Please proceed to parking space 9.
# Ticket 10 issued. Please proceed to parking space 10.
# Ticket 11 issued. Please proceed to parking space 11.
# Ticket 12 issued. Please proceed to parking space 12.
# Ticket 13 issued. Please proceed to parking space 13.
# Ticket 14 issued. Please proceed to parking space 14.
# Ticket 15 issued. Please proceed to parking space 15.
# ...
